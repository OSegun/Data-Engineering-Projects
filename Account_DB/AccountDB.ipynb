# %%
import psycopg2
import pandas as pd

# %%
def create_database():
    # connect to the default database postgres
    conn = psycopg2.connect("host=127.0.0.1 dbname=postgres user=postgres password=postgres")
    conn.set_session(autocommit=True)
    cur = conn.cursor()
    
    #cur.execute("DROP DATABASE accounts") # Drop existing database with the name accounts
    #cur.execute("CREATE DATABASE accounts") # create new databsae accounts
    
    #conn.close() # close connection with the database
    
    # connect to the new database accounts
    conn = psycopg2.connect("host=127.0.0.1 dbname=accounts user=postgres password=postgres")
    #conn.set_session(autocommit=True)
    cur = conn.cursor()
    
    return cur, conn

def drop_table(cur, conn):
    for query in drop_table_queries:
        cur.execute(query)
        conn.commit()

def create_table(cur, conn):
    for query in create_table_queries:
        cur.execute(query)
        conn.commit()

# %% [markdown]
# Download dataset from this link https://drive.google.com/drive/folders/1crEAKkiZg60oNKK37WzfpRo_M6E1MXSz

# %%
country_df = pd.read_csv('Wealth-AccountsCountry.csv')
country_df.head()
# Out:
#   Code                  Long Name         Income Group  \
# 0  ALB        Republic of Albania  Upper middle income
# 1  ARG         Argentine Republic  Upper middle income
# 2  ARM        Republic of Armenia  Upper middle income
# 3  AUS  Commonwealth of Australia          High income
# 4  AUT        Republic of Austria          High income
#
#                       Region Lending category Other groups      Currency Unit  \
# 0      Europe & Central Asia             IBRD          NaN       Albanian lek
# 1  Latin America & Caribbean             IBRD          NaN     Argentine peso
# 2      Europe & Central Asia             IBRD          NaN      Armenian dram
# 3        East Asia & Pacific              NaN          NaN  Australian dollar
# 4      Europe & Central Asia              NaN    Euro area               Euro
#
#                             Latest population census  \
# 0                                    2020 (expected)
# 1                                    2020 (expected)
# ...

# %%
country_df.columns
# Out:
# Index(['Code', 'Long Name', 'Income Group', 'Region', 'Lending category',
#        'Other groups', 'Currency Unit', 'Latest population census',
#        'Latest household survey', 'Special Notes',
#        'National accounts base year', 'National accounts reference year',
#        'System of National Accounts', 'SNA price valuation',
#        'Alternative conversion factor', 'PPP survey years',
#        'Balance of Payments Manual in use', 'External debt Reporting status',
#        'System of trade', 'Government Accounting concept',
#        'IMF data dissemination standard',
#        'Source of most recent Income and expenditure data',
#        'Vital registration complete', 'Latest agricultural census',
#        'Latest industrial data', 'Latest trade data',
#        'Latest water withdrawal data', '2-alpha code', 'WB-2 code',
#        'Table Name', 'Short Name'],
#       dtype='object')

# %%
new_country = country_df[['Code', 'Long Name', 'Currency Unit', 'Table Name', 'Short Name']]

# %%
new_country.isna().sum()
# Out:
# Code                5
# Long Name           3
# Currency Unit    7451
# Table Name       7451
# Short Name       7451
# dtype: int64

# %%
new_country.shape
# Out:
# (7597, 5)

# %%
new_country.tail(20)
# Out:
#      Code                            Long Name Currency Unit Table Name  \
# 7577  ZWE                             Zimbabwe           NaN        NaN
# 7578  ZWE                             Zimbabwe           NaN        NaN
# 7579  ZWE                             Zimbabwe           NaN        NaN
# 7580  ZWE                             Zimbabwe           NaN        NaN
# 7581  ZWE                             Zimbabwe           NaN        NaN
# 7582  ZWE                             Zimbabwe           NaN        NaN
# 7583  ZWE                             Zimbabwe           NaN        NaN
# 7584  ZWE                             Zimbabwe           NaN        NaN
# 7585  ZWE                             Zimbabwe           NaN        NaN
# 7586  ZWE                             Zimbabwe           NaN        NaN
# 7587  ZWE                             Zimbabwe           NaN        NaN
# 7588  ZWE                             Zimbabwe           NaN        NaN
# ...

# %%
new_country.to_csv('new_country', index=False)

# %%
acc_data_df = pd.read_csv('Wealth-AccountData.csv')
acc_data_df.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995] 1996 [YR1996] 1997 [YR1997] 1998 [YR1998] 1999 [YR1999]  \
# 0      4.49E+10      4.34E+10      3.71E+10      3.88E+10      4.22E+10
# 1      14072.79      13708.99       11794.1      12399.48      13573.26
# 2      3468.858      3355.549      2868.997      3013.391      3259.893
# 3      6507.931      6353.737      5466.692      5901.072       6492.73
# ...

# %%
acc_data_df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]', '1998 [YR1998]',
#        '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]',
#        '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]',
#        '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]',
#        '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
#        '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'],
#       dtype='object')

# %%
acc_data_df = acc_data_df.drop(['2002 [YR2002]',
       '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]',
       '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]',
       '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
       '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'], axis=1)

# %%
acc_data_df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]', '1998 [YR1998]',
#        '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]'],
#       dtype='object')

# %%
acc_series_df = pd.read_csv('Wealth-AccountSeries.csv')
acc_series_df.head()
# Out:
#              Code                                     Indicator Name  \
# 0       NW.HCA.TO                  Human capital (constant 2018 US$)
# 1       NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2  NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3  NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4  NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
#
#                                      Long definition  \
# 0  Human capital is computed as the present value...
# 1  Human capital is computed as the present value...
# 2  Human capital is computed as the present value...
# 3  Human capital is computed as the present value...
# 4  Human capital is computed as the present value...
#
#                                               Source          Topic  \
# 0  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 1  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# ...

# %%
acc_data_df.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995] 1996 [YR1996] 1997 [YR1997] 1998 [YR1998] 1999 [YR1999]  \
# 0      4.49E+10      4.34E+10      3.71E+10      3.88E+10      4.22E+10
# 1      14072.79      13708.99       11794.1      12399.48      13573.26
# 2      3468.858      3355.549      2868.997      3013.391      3259.893
# 3      6507.931      6353.737      5466.692      5901.072       6492.73
# ...

# %%
acc_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7592 entries, 0 to 7591
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   7592 non-null   object
#  1   Country Code   7592 non-null   object
#  2   Series Name    7592 non-null   object
#  3   Series Code    7592 non-null   object
#  4   1995 [YR1995]  7592 non-null   object
#  5   1996 [YR1996]  7592 non-null   object
#  6   1997 [YR1997]  7592 non-null   object
#  7   1998 [YR1998]  7592 non-null   object
#  8   1999 [YR1999]  7592 non-null   object
#  9   2000 [YR2000]  7592 non-null   object
#  10  2001 [YR2001]  7592 non-null   object
# dtypes: object(11)
# memory usage: 652.6+ KB

# %%
acc_series_df.columns
# Out:
# Index(['Code', 'Indicator Name', 'Long definition', 'Source', 'Topic',
#        'Unit of measure', 'Periodicity', 'Reference period',
#        'Statistical concept and methodology', 'Previous Indicator Code',
#        'Previous Indicator Name'],
#       dtype='object')

# %%
new_series = acc_series_df[['Code', 'Indicator Name', 'Long definition', 'Topic']]

# %%
new_series.head()
# Out:
#              Code                                     Indicator Name  \
# 0       NW.HCA.TO                  Human capital (constant 2018 US$)
# 1       NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2  NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3  NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4  NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
#
#                                      Long definition          Topic
# 0  Human capital is computed as the present value...  Human capital
# 1  Human capital is computed as the present value...  Human capital
# 2  Human capital is computed as the present value...  Human capital
# 3  Human capital is computed as the present value...  Human capital
# 4  Human capital is computed as the present value...  Human capital

# %%
new_series.to_csv('new_series', index=False)

# %%
cur, conn = create_database()

# %%
country_table = ("""CREATE TABLE IF NOT EXISTS account_country (
           country_code VARCHAR ,
           long_name VARCHAR ,
           currency_unit VARCHAR,
           table_name VARCHAR,
           short_name VARCHAR
           );
            """)
cur.execute(country_table)
conn.commit()

# %% [markdown]
# with open(r'new_country', 'r') as f:
#     next(f)  # Skip the header row. Or remove this line if csv has no header.
#     conn.cursor.copy_expert("""COPY account_country FROM STDIN WITH (FORMAT CSV)""", f)

# %%
series_table = ("""CREATE TABLE IF NOT EXISTS account_series (
           country_code VARCHAR,
           indicator_name VARCHAR PRIMARY KEY,
           long_definition VARCHAR,
           topic VARCHAR
           );
            """)
cur.execute(series_table)
conn.commit()

# %%
cur.execute("DROP TABLE account_data")

# %%
conn.commit()

# %%
data_table = ("""CREATE TABLE IF NOT EXISTS account_data (
           country_name VARCHAR, country_code VARCHAR, indicator_name VARCHAR, series_code VARCHAR,
           yr1995 VARCHAR, yr1996 VARCHAR, yr1997 VARCHAR, yr1998 VARCHAR, yr1999 VARCHAR, yr2000 VARCHAR, yr2001 VARCHAR
           );
            """)
cur.execute(data_table)
conn.commit()

# %%
"""
country_insert = (INSERT INTO account_country (
           country_code, long_name,
           currency_unit, table_name,
           short_name)
           VALUES (%s, %s, %s, %s, %s))

for i, row in new_country.iterrows():
    #print(list(row))
    cur.execute(country_insert, list(row))"""
import csv
import os

data1 = []
with open('new_country.txt', 'r') as f:
    next(f)
    reader = csv.reader(f)
    for row in reader:
        data1.append(row)
        
for dt in data1:
    cur.execute("INSERT INTO account_country VALUES (%s, %s, %s, %s, %s)", dt)

# %%
conn.commit()

# %%
series_insert = ("""INSERT INTO account_series (
           country_code, indicator_name,
           long_definition, topic)
           VALUES (%s, %s, %s, %s)""")

for i, row in new_series.iterrows():
    #print(list(row))
    cur.execute(series_insert, list(row))

# %%
conn.commit()

# %%
data_insert = ("""INSERT INTO account_data (
           Country_Name, Country_Code, Indicator_Name, Series_Code,
           YR1995, YR1996, YR1997, YR1998, YR1999, YR2000, YR2001 
           )
           VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)""")

for i, row in acc_data_df.iterrows():
    #print(list(row))
    cur.execute(data_insert, list(row))

# %%
conn.commit()

# %%
cur.close()
conn.close()
